# %% [markdown]
# # 🥊 Literacy Partners Competitive Positioning
# ## How to Win Every Comparison Conversation
# ---
# **Purpose:** Deep dive into how LP positions itself against each competitor
# in different selling situations — for use in proposals, demos, and objection handling.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings("ignore")
BRAND = {"primary": "#2E4057", "secondary": "#048A81", "accent": "#F18F01", "danger": "#C73E1D"}
print("Competitive Positioning Toolkit — Ready")

# %% [markdown]
# ## 🔬 Feature Comparison Matrix

# %%
comparison = pd.DataFrame({
    "Feature": [
        "Science of Reading Alignment",
        "Ongoing Coaching (not just workshops)",
        "Tailored to each school",
        "Relationship with school staff",
        "Evidence-based methodology",
        "Founder-led expertise (Dahlia Dallal)",
        "LA Metro presence & relationships",
        "Works with ALL curriculum providers",
        "Teacher retention impact",
        "Price-to-impact ratio",
    ],
    "Literacy Partners": ["✅"]*10,
    "TCRWP":         ["❌","❌","⚠️","✅","⚠️","⚠️","❌","⚠️","⚠️","⚠️"],
    "Curriculum Assoc": ["✅","❌","❌","❌","✅","❌","⚠️","⚠️","❌","❌"],
    "Amplify":        ["✅","❌","❌","❌","✅","❌","⚠️","❌","❌","❌"],
    "Fountas & Pinnell": ["⚠️","✅","⚠️","⚠️","⚠️","⚠️","❌","⚠️","⚠️","⚠️"],
})

print("LP COMPETITIVE FEATURE COMPARISON")
print("=" * 90)
print(comparison.to_string(index=False))
print()
print("Legend: ✅ Strong  ⚠️ Partial  ❌ Weak/Missing")
print()
print("LP is the ONLY vendor with all 10 features rated Strong.")

# %% [markdown]
# ## 🧭 Win/Loss Selling Situations
#
# When you hear each competitor name, here is your full game plan.
# See `02_competitive_research/pd_provider_landscape_analysis.ipynb` for battle cards.
#
# ### Key Principle: LP Does NOT Compete — It Completes
# For curriculum vendors (Amplify, i-Ready, Heinemann):
# LP is the coaching infrastructure that makes their product work.
# Never say 'we are better than X.' Say: 'We make X more effective.'

# %%
win_situations = pd.DataFrame([
    {"Situation": "District already has i-Ready",
     "LP Angle": "LP is the coaching layer i-Ready doesn't provide",
     "Win Rate Est": "85%"},
    {"Situation": "District uses TCRWP / Balanced Literacy",
     "LP Angle": "LP is the SOR transition partner — direct replacement",
     "Win Rate Est": "70%"},
    {"Situation": "District uses Amplify CKLA",
     "LP Angle": "LP maximizes CKLA fidelity with ongoing coaching",
     "Win Rate Est": "80%"},
    {"Situation": "No current PD provider",
     "LP Angle": "LP is the gold standard — come in as the first and only",
     "Win Rate Est": "90%"},
    {"Situation": "District has tight budget",
     "LP Angle": "Title I + ESSER funding — no new money needed",
     "Win Rate Est": "60%"},
])

print("WIN RATE BY SELLING SITUATION (estimated)")
print(win_situations.to_string(index=False))
